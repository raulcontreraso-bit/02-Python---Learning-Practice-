# %% [markdown]
# <img src="img/viu_logo.png" width="200">
#
# ## 01MIAR - Python para Inteligencia Artificial
# ### Presentación de la asignatura
#
# ![logo](img/python_logo.png)
#
# *Ivan Fuertes / Franklin Alvarez*

# %% [markdown]
# ## Presentación
#
# Profesores:
# - Grupo A: Iván Fuertes - ivan.fuertes@professor.universidadviu.com
# - Grupo B: Franklin Alvarez - falvarezc@professor.universidadviu.com

# %% [markdown]
# ## Objetivos
# - Diseñar e implementar programas básicos en Python
# - Conocer cómo desarrollar scripts y Jupyter Notebook
# - Saber importar y configurar módulos externos comunes en un entorno propio
# - Familiarización con modulos para análisis de datos (NumPy, pandas, matplotlib)
# - Conocer las técnicas básicas de análisis de datos

# %% [markdown]
# ## Metodología
#
# - Clase Expositiva
# - Actividad en Grupo
# - Problemas
# - Foros
# - Trabajo Autónomo

# %% [markdown]
# #### Sesiones
#
# | Sesión | Descripción                    | Grupo A                | Grupo B               |
# |:-------|:-------------------------------| :----------------------| :---------------------|
# | VC 00  | Tutoria Colectiva Presentación | 22-04-26 @ 18:00/20:00 | 22-04-26 @ 20:00/22:00|
# | VC 01  | T01 Intro Python               | 27-04-26 @ 18:00/20:00 | 27-04-26 @ 20:00/22:00|
# | VC 02  | T02 Tipos de Datos             | 29-04-26 @ 18:00/20:00 | 29-04-26 @ 20:30/22:30|
# | VC 03  | T03 Estructuras de Control     | 04-05-26 @ 18:00/20:00 | 04-05-26 @ 20:00/22:00|
# | VC 04  | T04 Funciones                  | 06-05-26 @ 18:00/20:00 | 06-05-26 @ 20:30/22:30|
# | VC 05  | T05 Ficheros                   | 11-05-26 @ 18:00/20:00 | 11-05-26 @ 20:00/22:00|
# | VC 06  | T06+07 OOP y Python Avanzado   | 13-05-26 @ 18:00/20:00 | 13-05-26 @ 20:30/22:30|
# | VC 07  | T08 NumPy                      | 18-05-26 @ 18:00/20:00 | 18-05-26 @ 20:00/22:00|
# | VC 08  | T09 Pandas                     | 20-05-26 @ 18:00/20:00 | 20-05-26 @ 20:30/22:30|
# | VC 09  | T10 Más Pandas                 | 25-05-26 @ 18:00/20:00 | 25-05-26 @ 20:00/22:00|
# | VC 10  | T11 Visualización de Datos     | 27-05-26 @ 18:00/20:00 | 27-05-26 @ 20:30/22:30|
# | VC 11  | T12 Procesamiento de Datos     | 01-06-26 @ 18:00/20:00 | 08-06-26 @ 20:00/22:00|
# | VC 12  | T13 Generadores                | 08-06-26 @ 18:00/20:00 | 12-06-26 @ 18:00/20:00|
#
# #### Prácticas
#
# | Sesión | Descripción                    | Grupo A                                         ||| Grupo B               |||
# |:-------|:-------------------------------| :--------| :----------------| :-------------------| :--------| :----------------| :-------------------------|
# | PT 01  | T01 - T05                      | 14-05-26 | G1 @ 18:00/20:00 | G2+G3 @ 20:00/22:00 | 14-05-26 | G1 @ 18:00/20:00 | G2+G3 @ 20:00/22:00 |
# | PT 02  | T08 - T13                      | 15-06-26 | G1 @ 18:00/20:00 | G2+G3 @ 20:00/22:00 | 15-06-26 | G1 @ 18:00/20:00 | G2+G3 @ 20:00/22:00 |

# %% [markdown]
# ## Comunicación
# - Blackboard, Foro
# - Clases Online
# - Email
#   - Grupo A: ivan.fuertes@professor.universidadviu.com
#   - Grupo B: falvarezc@professor.universidadviu.com
# - Soporte, soporte@campusviu.es

# %% [markdown]
# ## Recursos de la asignatura
# - En el aula virtual
#  - Manual de la asignatura en el aula virtual
#  - Jupyter notebooks de las clases
#  - Actividades (descripción y entregas)
# - GitHub (enviar usuario al profesor) - https://github.com/fyac44/01MIAR_ABR26

# %% [markdown]
# - Documentación oficial
#  - Python: https://docs.python.org/3/
#  - NumPy: https://docs.scipy.org/doc/
#  - pandas: https://pandas.pydata.org/index.html
#  - matplotlib: https://matplotlib.org/

# %% [markdown]
# ## Actividades y Entregas
#
#
# |Nombre | Tipo | Entrega | Peso [%]| 1era convocatoria | 2da convocatoria |
# | ---- | ---- | ---- | ---- | ---- | ---- |
# |Video |  Portfolio | Notebook | 10 | (Disponible el 30/05/2026) 31/05/2026 - 08:00 | **No disponible** |
# |Foro |  Portfolio | Entradas en foro | 10 | 03/08/2026 - 08:00 | **No disponible** |
# |Dataset |  Portfolio | Notebook | 30 | 03/08/2026 - 08:00 | 21/09/2029 - 08:00 |
# |Whitepaper |  Portfolio | Notebook | 10 | 08/06/2026 - 08:00 | 21/09/2029 - 08:00 |
# |Examen |  Examen | Preguntas | 40 | 31/07/2026 (Franjas mañana y tarde) | 18/09/2026 (Franjas mañana y tarde) |
#
# ### Franjas horarias para examen
# - Franja Mañana: 12:00 - 14:00 (CEST)
# - Franja Tarde: 20:00 - 22:00 (CEST)

# %% [markdown]
# ## Aprobación de la asignatura
#
# - Tanto el examen cómo el portafolio deben estar aprobados para aprobar la asignatura.
# - Si no se ha aprobado el examen o el portafolio, se colocará una nota máxima de 4.0 puntos.
# - No presentar el examen equivale a un ***No Presentado*** en las actas, aún cuando hayan entregado actividades del portafolio.
#
# #### Normas para segunda convocatoria
#
# - Si un alumno aprueba en primera convocatoria no aparecerá en las actas de segunda convocatoria.
# - Todas las notas (aprobadas o no) en primera convocatoria, se toman en cuenta para segunda convocatoria.
# - Del portafolio, solamente se pueden entregar aquellas actividades no aprobadas en primera convocatoria.
# - No presentar el examen (si no se aprobó en primera convocatoria) equivale a un ***No Presentado*** en las actas, aún cuando hayan entregado actividades del portafolio.
# - No hay ***Foro*** ni actividad de ***Video*** en segunda convocatoria.

# %% [markdown]
# ## Foros
# ### Introducción
# - Generar Ideas Nuevas y Llegar a Nuevos Conocimientos
# - Sentido Crítico y Concluir con Medidas, Soluciones o Nuevos Enfoques
# - Desarrollo de Temas Relacionando Inteligencia Artificial y el Uso de Herramientas de Programación, en concreto Python, aportación de Referencias
#
# ### Grupos
# - Asignación aleatoria
# - Discusión de un tema distintos en cada grupo propuesto por el profesor
#
# ### Evaluación
# - 10% de la Nota Final
# - Sólo se Podrá Participar en Primera Convocatoria.
# - Mínimo para Obtener una Nota Será de Dos Participaciones

# %% [markdown]
# ## Examen Demo
# - 13-06-26 - 18.00
# - Se replica el entorno del examen real
#   - SMOWL
#   - Restricciones habituales
#   - Notebook con preguntas
#   - No evaluable
# - Si hay incidencias se comunican al alumno

# %% [markdown]
# ## Encuestas de Feedback
# - Importante participar
#   - 2 minutos
#   - Nos aporta información relevante acerca de vuestra opinión
# - Disponibles en página principal de plataforma
# - Incentivar participación
#   - Si día 22-06-26 se alcanza el 50% de participación
#   - Se publican todos los exámenes de ediciones anteriores corregidos

# %% [markdown]
# ## Instalación local
#
# Se puede optar por las siguientes configuraciones:
# - Local con Anaconda
#   - Incluye módulos para el curso (__NumPy__, __pandas__, __matplotlib__, __jupyter notebook__...)
#   - http://docs.anaconda.com/anaconda/install/
#   - https://www.anaconda.com/docs/getting-started/getting-started
#   - [Entornos virtuales en Anaconda](https://medium.com/@e.osovngas/tutorial-conda-enviroment-d93542dcea98)
# - Docker container
# - Instalar Python y entorno virtual
#   - Guía de instalación (para Windows, Linux y macOS): https://realpython.com/installing-python/
#   - [Descargas Python](https://www.python.org/downloads/) [3.9, 3.12]*
#   - No olvidéis marcar el checkbox con la opción de añadir Python a la variable de entorno PATH.
# - Google colab
# - IDEs: VSCode, PyCharm...
#
#
# $*$  [Tensorflow requirements](https://www.tensorflow.org/install/pip) Python 3.9 a 3.12

# %% [markdown]
# ## Uso de Jupyter Lab / Jupyter Notebook
# - Permite intercalar el código con las explicaciones necesarias.
# - Presentaciones, ejercicios, actividades... __todo__ notebooks
# - Markdown/HTML + codigo en vivo
# - Markdown = https://www.markdownguide.org/
# - Facilita la colaboración y la presentación interactiva de código
# - Instalación
#   - *pip install jupyterlab*
#   - [Jupyter-lab](https://jupyter.org/install)
# - Levantar server
#   - En la terminal: __jupyter lab__ o __jupyter notebook__
# - Archivos _.ipynb_
# - Documentación https://jupyter.readthedocs.io/en/latest/

# %% [markdown]
# ## Contenidos
#
# #### Introducción a la sintaxis de Python 3

# %%
from platform import python_version

# Verificar versión de Python
print(python_version())

# %%
# Hello world!!
a = 15

# %%
print(f"el valor {a} para la variable")

# %%
# funcion para sumar dos elementos
def mult(a,b):
    return a * b

# %%
lista = [1,2,3]

for i,value in enumerate(lista):
    lista[i] = mult(value, 10)

print(lista)

# %% [markdown]
# #### Colecciones
#
# #### Uso de librerías fundamentales
# - NumPy

# %%
import numpy as np

random_list = np.random.randint(200,size=(10,2))
random_list

# %% [markdown]
# - pandas

# %%
import pandas as pd

frame = pd.DataFrame(random_list)
frame

# %% [markdown]
# - matplotlib & seaborn

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
frame.plot()
plt.show()

# %% [markdown]
# #### Introducción a análisis de datos en Python
# - Trabajar con strings
# - Limpieza de datos
# - Escritura y lectura de datos

# %% [markdown]
# ### Homework Jupyter notebook
# - Entorno Anaconda + Python + Jupyter Notebook instalado
# - Creación de notebooks
# - Creación de tipos de celdas
#   - Markdown para texto e imágenes
#   - Code para código
# - Revisar los atajos de teclado e interiorizarlos
